2,5,1,6,7,8],[3,5,6,7,8,4,3,6,5,7],[2,2,4,4,5,6,8,8,9,9],[7,9,5,2,1,3,5,7,6,7],[1,9,6,1,1,9,6,1,1,1],[3,6,6,9,1,4,8,8,3,2],[8,9,4,4,5,1,2,8,9,1],[6,8,2,1,7,5,2,1,8,2],[1,2,2,5,6,7,8,5,9,2],[8,5,4,2,2,9,7,6,3,4],[7,9,5,2,1,3,5,7,6,7],[7,7,2,8,5,6,9,8,3,3],[4,5,3,7,2,9,1,2,6,2]])
#for i in range(len(mas2)):
    #print(len(mas2[i]),mas2[i])
# Вычислить среднее значение на каждой позиции
means1 = np.mean(mas1, axis=0)
means2 = np.mean(mas2, axis=0)
means3 = np.mean(mas3, axis=0)
# 2,7,5,1,6,6,3,3,3,8
print(len(mas1)+len(mas2)+len(mas3))
allmas = [len(mas1), len(mas2), len(mas3)]
name=['1 состояние','2 состояние','3 состояние']
plt.pie(allmas, labels=name,autopct='%1.1f%%')
plt.title('Отчет по опросам')
plt.legend()
plt.show()
# Out:
# 147

# %%
# Регрессия 1 состояния
x = np.arange(10)
y = means1
# коэфиценты
coefficients = np.polyfit(x, y, 1)
p = np.poly1d(coefficients)
plt.scatter(x, y)
plt.plot(x, p(x), 'r')
plt.show()

# %%
# Регрессия 2 состояния
x = np.arange(10)
y = means2
# коэфиценты
coefficients = np.polyfit(x, y, 1)
p = np.poly1d(coefficients)
plt.scatter(x, y)
plt.plot(x, p(x), 'r')
plt.show()

# %%
# Регрессия 3 состояния
x = np.arange(10)
y = means3
# коэфиценты
coefficients = np.polyfit(x, y, 1)
p = np.poly1d(coefficients)
plt.scatter(x, y)
plt.plot(x, p(x), 'r')
plt.show()

# %%
# нижние числа от 1 до 10 для позиции
x = list(range(10))
plt.xlabel('Позиция чисел в массиве')
plt.ylabel('Средние числа')
plt.title('Массив 1')
plt.plot(x, means1)
plt.show()

# %%
plt.xlabel('Позиция чисел в массиве')
plt.ylabel('Средние числа')
plt.title('Массив 2')
plt.plot(x, means2)
plt.show()

# %%
plt.xlabel('Позиция чисел в массиве')
plt.ylabel('Средние числа')
plt.title('Массив 3')
plt.plot(x, means3)
plt.show()

# %%
x1=input()
mas=[]
r=0
for char in x1[:20]:
    try:
        mas.append(int(char))
    except ValueError:
        pass
er1=0
er2=0
er3=0
for i in range(10):
    if len(mas)!=10:
        print("Ошибка! Длинна массива не равна 10")
        break
    er1+=(means1[i]-int(mas[i]))**2
    er2+=(means2[i]-int(mas[i]))**2
    er3+=(means3[i]-int(mas[i]))**2
if er1<er2 and er1<er3:
    print("1 состояние")
    plt.plot(x, means1,label='Первое состояние')
    r=1
if er2<er1 and er2<er3:
    print("2 состояние")
    plt.plot(x, means2,label='Второе состояние')
    r=2
if er3<er2 and er3<er1:
    print("3 состояние")
    plt.plot(x, means3,label='Третье состояние')
    r=3
plt.xlabel('Позиция чисел в массиве')
plt.ylabel('Средние числа')
plt.title('Входные данные')
plt.plot(x, mas,label='Указанные данные')
plt.legend()
plt.show()
# Out:
# 3,8,9,7,2,5,6,1,9,3
# 1 состояние

# %%
p1=0
p2=0
p3=0
for i1 in range(len(mas1)):
    for i11 in range(10):
        p1+=((mas1[i1][i11])-int(mas[i11]))**2
    plt.plot(x, mas1[i1])
p1=p1/len(mas1)
for i2 in range(len(mas2)):
    for i21 in range(10):
        p2+=((mas2[i2][i21])-int(mas[i21]))**2
p2=p2/len(mas2)
for i3 in range(len(mas3)):
    for i31 in range(10):
        p3+=((mas3[i3][i31])-int(mas[i31]))**2
p3=p3/len(mas3)
print(p1,p2,p3)
plt.xlabel('Позиция чисел в массиве')
plt.ylabel('Средние числа')
plt.title('Все данные 1 состояния')
plt.show()
# Out:
# 132.91176470588235 136.4047619047619 138.10344827586206

# %%
if r==1 and p1<p2 and p1<p3:
    print('У вас 1 состояние')
if r==2 and p2<p1 and p2<p3:
    print('У вас 2 состояние')
if r==3 and p3<p2 and p3<p1:
    print('У вас 3 состояние')
if r==1 and p1>p2 and p1<p3:
    print('У вас, возможно, 1 состояние, но оно близко ко 2')
if r==2 and p2>p1 and p2<p3:
    print('У вас, возможно, 2 состояние, но оно близко к 1')
if r==3 and p3>p2 and p3<p1:
    print('У вас, возможно, 3 состояние, но оно близко ко 2')
if r==1 and p1<p2 and p1>p3:
    print('У вас, возможно, 1 состояние, но оно близко к 3')
if r==2 and p2<p1 and p2>p3:
    print('У вас, возможно, 2 состояние, но оно близко к 3')
if r==3 and p3<p2 and p3>p1:
    print('У вас, возможно, 3 состояние, но оно близко к 1')
# Out:
# У вас 1 состояние

# %%
b=[]
t=0
f=0
e1=0
e2=0
e3=0
for a1 in range(len(mas1)):
    b=mas1[a1]
    for a in range(10):
        e1+=(means1[a]-int(b[a]))**2
        e2+=(means2[a]-int(b[a]))**2
        e3+=(means3[a]-int(b[a]))**2
    if e1<e2 and e1<e3:
        t+=1
    else:
        f+=1
    e1=0
    e2=0
    e3=0
for a2 in range(len(mas2)):
    b=mas2[a2]
    for a in range(10):
        e1+=(means1[a]-int(b[a]))**2
        e2+=(means2[a]-int(b[a]))**2
        e3+=(means3[a]-int(b[a]))**2
    if e2<e1 and e2<e3:
        t+=1
    else:
        f+=1
    e1=0
    e2=0
    e3=0
for a3 in range(len(mas3)):
    b=mas3[a3]
    for a in range(10):
        e1+=(means1[a]-int(b[a]))**2
        e2+=(means2[a]-int(b[a]))**2
        e3+=(means3[a]-int(b[a]))**2
    if e3<e2 and e3<e1:
        t+=1
    else:
        f+=1
    e1=0
    e2=0
    e3=0
print(t,f)
print('Точность нашего алгоритма:',t/(t+f))
# Out:
# 87 60
# Точность нашего алгоритма: 0.5918367346938775
